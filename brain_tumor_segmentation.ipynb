jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-919.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2199.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1228.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2909.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-297.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-131.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-392.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1435.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-1701.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2550.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1670.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-893.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-1157.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2168.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1742.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-525.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-427.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2887.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-47.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1129.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-835.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2626.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2455.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1730.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-284.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2724.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2930.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1433.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-844.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-626.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2417.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2357.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2549.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2210.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-2609.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2955.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-507.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-990.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1658.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2001.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-510.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1141.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2242.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1486.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1324.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1319.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-1667.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1332.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-106.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2249.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-2985.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1907.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-3049.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2227.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1506.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2763.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2913.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2259.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2321.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2083.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2318.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2220.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1891.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-695.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2506.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2543.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1278.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2922.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-759.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1781.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2949.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1502.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-953.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-680.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1315.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1251.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2504.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-853.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2727.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2025.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2111.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-3027.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-358.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1818.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-341.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1119.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2635.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2731.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2349.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-108.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1578.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2786.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1061.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1007.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-311.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1680.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2055.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-23.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1497.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-630.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2219.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-428.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-237.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2264.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2580.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-1235.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2145.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-3013.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-498.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1824.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-410.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-805.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-878.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2027.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-201.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-849.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-975.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-497.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2208.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2240.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-160.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1971.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1014.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2574.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2164.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1399.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2817.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-927.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1260.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2079.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2087.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1008.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1431.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2340.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-46.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2685.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1902.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1895.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-252.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-656.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2821.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1973.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1297.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-776.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2434.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-40.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2888.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-157.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2149.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-49.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2619.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2310.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-572.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1151.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1347.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-717.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-326.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1815.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2045.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-3055.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2186.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-16.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1544.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2517.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1184.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1607.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-473.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1915.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1403.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1884.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2706.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1632.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2739.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-925.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-775.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-803.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2862.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1708.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2755.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-2119.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2416.jpg
# /kaggle/input/masks-and-images-final/training/masks/pituitary-mask-107.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-834.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-312.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2353.jpg
# /kaggle/input/masks-and-images-final/training/masks/glioma-mask-1407.jpg
# /kaggle/input/masks-and-images-final/training/masks/meningioma-mask-2431.jpg

# %%
import glob
import os
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.layers as K
from tqdm import tqdm
import cv2
import numpy as np

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

smooth = 1e-15
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + 100) / (sum_ - intersection + 100)
    return jac      
    return iou_score
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, UpSampling2D
from tensorflow.keras.layers import AveragePooling2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50

""" Atrous Spatial Pyramid Pooling """
def ASPP(inputs):
    shape = inputs.shape

    y_pool = AveragePooling2D(pool_size=(shape[1], shape[2]), name='average_pooling')(inputs)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)
    y_pool = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y_pool)

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(inputs)
    y_1=Conv2D(filters=128, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y_1)
    y_1 = BatchNormalization()(y_1)
    y_1 = Activation('relu')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same', use_bias=False)(inputs)
    y_6 = BatchNormalization()(y_6)
    y_6 = Activation('relu')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same', use_bias=False)(inputs)
    y_12 = BatchNormalization()(y_12)
    y_12 = Activation('relu')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same', use_bias=False)(inputs)
    y_18 = BatchNormalization()(y_18)
    y_18 = Activation('relu')(y_18)

    y = Concatenate()([y_pool, y_1, y_6, y_12, y_18])

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    return y

def DeepLabV3Plus(shape):
    """ Inputs """
    inputs = Input(shape)

    """ Pre-trained ResNet50 """
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=inputs)

    """ Pre-trained ResNet50 Output """
    image_features = base_model.get_layer('conv4_block6_out').output
    x_a = ASPP(image_features)
    x_a = UpSampling2D((4, 4), interpolation="bilinear")(x_a)

    """ Get low-level features """
    x_b = base_model.get_layer('conv2_block2_out').output
    x_b = Conv2D(filters=48, kernel_size=1, padding='same', use_bias=False)(x_b)
    x_b = BatchNormalization()(x_b)
    x_b = Activation('relu')(x_b)

    x = Concatenate()([x_a, x_b])

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = UpSampling2D((4, 4), interpolation="bilinear")(x)

    """ Outputs """
    x = Conv2D(1, (1, 1), name='output_layer')(x)
    x = Activation('sigmoid')(x)

    """ Model """
    model = Model(inputs=inputs, outputs=x)
    return model

if __name__ == "__main__":
    input_shape = (256,256, 3)
    model = DeepLabV3Plus(input_shape)
    model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 5s 0us/step
# 94781440/94765736 [==============================] - 5s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 130, 130, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 64, 64, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 64, 64, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 64, 64, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 64, 64, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 64, 64, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 64, 64, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 64, 64, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 64, 64, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 64, 64, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 64, 64, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 64, 64, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 64, 64, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 64, 64, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 64, 64, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 64, 64, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 32, 32, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 32, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 32, 32, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 32, 32, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 32, 32, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 32, 32, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 32, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 32, 32, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 32, 32, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 32, 32, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 32, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 32, 32, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 32, 32, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 32, 32, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 32, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 32, 32, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 32, 32, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 32, 32, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 16, 16, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 16, 16, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 16, 16, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 16, 16, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 16, 16, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 16, 16, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 16, 16, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 16, 16, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 16, 16, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 16, 16, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 16, 16, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 16, 16, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 16, 16, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 16, 16, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 16, 16, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 16, 16, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 16, 16, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 16, 16, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 16, 16, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 16, 16, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 16, 16, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 16, 16, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 16, 16, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 16, 16, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# average_pooling (AveragePooling (None, 1, 1, 1024)   0           conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 1, 256)    262144      average_pooling[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 256)  262144      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# bn_1 (BatchNormalization)       (None, 1, 1, 256)    1024        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  32768       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 256)  2359296     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  2359296     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 256)  2359296     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# relu_1 (Activation)             (None, 1, 1, 256)    0           bn_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 16, 16, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 256)  0           relu_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 16, 16, 128)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 256)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1152) 0           up_sampling2d[0][0]
#                                                                  activation[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  294912      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 48)   12288       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 48)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 48)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 304)  0           up_sampling2d_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  700416      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 256)  589824      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 256 0           activation_7[0][0]
# __________________________________________________________________________________________________
# output_layer (Conv2D)           (None, 256, 256, 1)  257         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 1)  0           output_layer[0][0]
# ==================================================================================================
# Total params: 17,829,697
# Trainable params: 17,795,169
# Non-trainable params: 34,528
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers

def Deeplabv3Plus(input_shape, num_classes):
    
    # Input layer
    inputs = layers.Input(shape=input_shape)
    
    # Backbone (encoder) module
    backbone = tf.keras.applications.Xception(include_top=False, weights='imagenet', input_tensor=inputs)
    x = backbone.output
    
    # Atrous Spatial Pyramid Pooling (ASPP) module
    x = layers.Conv2D(filters=256, kernel_size=1, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.DepthwiseConv2D(kernel_size=3, strides=(1, 1), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters=256, kernel_size=1, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(units=256, activation='relu')(x)
    x = layers.Dropout(rate=0.5)(x)
    x = layers.Dense(units=num_classes, activation='softmax')(x)
    
    # Decoder module with attention mechanism
    x_skip = backbone.get_layer('block3_sepconv2_act').output
    x = layers.Attention()([x, x_skip])
    x = layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(rate=0.5)(x)
    x = layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(rate=0.5)(x)
    x = layers.Conv2D(filters=num_classes, kernel_size=1, padding='same', activation='sigmoid')(x)
    
    # Create model
    model = tf.keras.models.Model(inputs=inputs, outputs=x)
    
    return model

# %%
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
H = 256
W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.jpg")))
    masks = sorted(glob(os.path.join(path, "masks", "*.jpg")))

    split_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=split_size, random_state=42)

    return (train_x, train_y), (test_x, test_y), (valid_x, valid_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x=x/255.
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))   ## (h, w) ## (h, w)
    x=x/255.
    x = x.astype(np.float32)    ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)

       
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

# %%
def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
if __name__ == "__main__":
    
    np.random.seed(42)
    tf.random.set_seed(42)

    
    create_dir("files")

    
    batch_size = 8
    lr = 1e-4
    num_epochs = 500
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "log.csv")

   
    dataset_path = "/kaggle/input/masks-and-images-final/training"
    
    (train_x, train_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    #print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test : {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(test_x, test_y, batch=batch_size)

    
    

    callbacks = [
            
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
            CSVLogger(csv_path),
            EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
        ]
    

    model =Deeplabv3Plus((H, W, 3),1)
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])
    model.fit(
                train_dataset,
                epochs=num_epochs,
                validation_data=valid_dataset,
callbacks=callbacks
            )

# %%
def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
for x, y in tqdm(zip(train_x, train_y), total=len(train_y)):
    name = x.split("/")[-1]

    """ Reading the image """
    image = cv2.imread(x, cv2.IMREAD_COLOR) ## [H, w, 3]
    image = cv2.resize(image, (W, H))       ## [H, w, 3]
    x = image/255.0                         ## [H, w, 3]
    x = np.expand_dims(x, axis=0)           ## [1, H, w, 3]

    """ Reading the mask """
    mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (W, H))

    """ Prediction """
    y_pred = model.predict(x, verbose=0)[0]
    y_pred = np.squeeze(y_pred, axis=-1)
    y_pred = y_pred >= 0.5
    y_pred = y_pred.astype(np.int32)

    """ Saving the prediction """
    save_image_path = os.path.join("/kaggle/working", name)
    save_results(image, mask, y_pred, save_image_path)

# %%
model.save('/kaggle/working/files/Deeplabv3ownnew.h5')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
x = np.expand_dims(test_x, axis=0)

# %%
model.evaluate(valid_dataset)
# Out:
# 77/77 [==============================] - 4s 56ms/step - loss: 0.1635 - dice_coef: 0.8368
# [0.16348615288734436, 0.8368437886238098]
